# %% [markdown]
# <a href="https://colab.research.google.com/github/robinrj6/ControlNet_revamp/blob/main/notebook_without_attention.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dataset management for UNET
# - In this, we will use only the 50% (25k) target images of the dataset.

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.13.0.92)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from opencv-python) (2.0.2)

# %%
# !wget https://huggingface.co/datasets/fusing/fill50k/resolve/main/images.zip
# !unzip images.zip
# !rm images.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: images/45164.png
#   inflating: images/3468.png
#   inflating: images/44408.png
#   inflating: images/42760.png
#   inflating: images/45431.png
#   inflating: images/7607.png
#   inflating: images/25051.png
#   inflating: images/33164.png
#   inflating: images/23211.png
#   inflating: images/29849.png
#   inflating: images/46520.png
#   inflating: images/6969.png
#   inflating: images/43511.png
#   inflating: images/8776.png
#   inflating: images/44598.png
#   inflating: images/8711.png
#   inflating: images/7442.png
#   inflating: images/23714.png
#   inflating: images/35138.png
#   inflating: images/24725.png
#   inflating: images/803.png
#   inflating: images/5287.png
#   inflating: images/26535.png
#   inflating: images/7861.png
#   inflating: images/24858.png
#   inflating: images/15836.png
#   inflating: images/16529.png
#   inflating: images/34016.png
#   inflating: images/26861.png
#   inflating: images/35660.png
#   inflating: images/35870.png
#   inflating: images/42678.png
#   inflating: images/44311.png
#   inflating: images/5868.png
#   inflating: images/12916.png
#   inflating: images/16650.png
#   inflating: images/49917.png
#   inflating: images/20749.png
#   inflating: images/40519.png
#   inflating: images/27348.png
#   inflating: images/29042.png
#   inflating: images/3703.png
#   inflating: images/31627.png
#   inflating: images/24270.png
#   inflating: images/41656.png
#   inflating: images/21121.png
#   inflating: images/5280.png
#   inflating: images/22708.png
#   inflating: images/32269.png
#   inflating: images/30751.png
#   inflating: images/36643.png
#   inflating: images/46418.png
#   inflating: images/21412.png
#   inflating: images/28027.png
#   inflating: images/7756.png
#   inflating: images/3256.png
#   inflating: images/48735.png
#   inflating: images/16637.png
#   inflating: images/46368.png
#   inflating: images/36019.png
#   inflating: images/7063.png
#   inflating: images/4527.png
#   inflating: images/9549.png
#   inflating: images/18497.png
#   inflating: images/1082.png
#   inflating: images/36741.png
#   inflating: images/33518.png
#   inflating: images/37295.png
#   inflating: images/49586.png
#   inflating: images/43638.png
#   inflating: images/29263.png
#   inflating: images/18630.png
#   inflating: images/3387.png
#   inflating: images/12452.png
#   inflating: images/18457.png
#   inflating: images/26999.png
#   inflating: images/44884.png
#   inflating: images/8450.png
#   inflating: images/48803.png
#   inflating: images/18328.png
#   inflating: images/20958.png
#   inflating: images/24687.png
#   inflating: images/21525.png
#   inflating: images/16685.png
#   inflating: images/40068.png
#   inflating: images/19072.png
#   inflating: images/19461.png
#   inflating: images/12339.png
#   inflating: images/36729.png
#   inflating: images/40512.png
#   inflating: images/42897.png
#   inflating: images/27186.png
#   inflating: images/4359.png
#   inflating: images/18896.png
#   inflating: images/20395.png
#   inflating: images/5236.png
#   inflating: images/10996.png
#   inflating: images/32710.png
#   inflating: images/36631.png
#   inflating: images/21271.png
#   inflating: images/30092.png
#   inflating: images/8616.png
#   inflating: images/28036.png
#   inflating: images/27914.png
#   inflating: images/43823.png
#   inflating: images/22943.png
#   inflating: images/20007.png
#   inflating: images/12349.png
#   inflating: images/15415.png
#   inflating: images/9014.png
#   inflating: images/15054.png
#   inflating: images/33545.png
#   inflating: images/40965.png
#   inflating: images/7827.png
#   inflating: images/44718.png
#   inflating: images/11971.png
#   inflating: images/28864.png
#   inflating: images/10662.png
#   inflating: images/6863.png
#   inflating: images/36731.png
#   inflating: images/7532.png
#   inflating: images/28236.png
#   inflating: images/4846.png
#   inflating: images/14027.png
#   inflating: images/2698.png
#   inflating: images/39104.png
#   inflating: images/20029.png
#   inflating: images/44118.png
#   inflating: images/44466.png
#   inflating: images/11656.png
#   inflating: images/18481.png
#   inflating: images/43912.png
#   inflating: images/18066.png
#   inflating: images/43750.png
#   inflating: images/13607.png
#   inflating: images/33027.png
#   inflating: images/24367.png
#   inflating: images/34568.png
#   inflating: images/22297.png
#   inflating: images/38259.png
#   inflating: images/17094.png
#   inflating: images/18138.png
#   inflating: images/28095.png
#   inflating: images/9091.png
#   inflating: images/24776.png
#   inflating: images/5427.png
#   inflating: images/39362.png
#   inflating: images/31335.png
#   inflating: images/45322.png
#   inflating: images/46614.png
#   inflating: images/8793.png
#   inflating: images/38091.png
#   inflating: images/35573.png
#   inflating: images/17785.png
#   inflating: images/16896.png
#   inflating: images/21330.png
#   inflating: images/7622.png
#   inflating: images/6875.png
#   inflating: images/20887.png
#   inflating: images/20396.png
#   inflating: images/30748.png
#   inflating: images/26945.png
#   inflating: images/19432.png
#   inflating: images/48798.png
#   inflating: images/6691.png
#   inflating: images/39250.png
#   inflating: images/37324.png
#   inflating: images/25020.png
#   inflating: images/25114.png
#   inflating: images/44638.png
#   inflating: images/12560.png
#   inflating: images/20507.png
#   inflating: images/24656.png
#   inflating: images/29829.png
#   inflating: images/22862.png
#   inflating: images/44207.png
#   inflating: images/46596.png
#   inflating: images/20508.png
#   inflating: images/47304.png
#   inflating: images/41934.png
#   inflating: images/44185.png
#   inflating: images/25477.png
#   inflating: images/6893.png
#   inflating: images/32776.png
#   inflating: images/46036.png
#   inflating: images/41436.png
#   inflating: images/2286.png
#   inflating: images/31095.png
#   inflating: images/38792.png
#   inflating: images/32596.png
#   inflating: images/13533.png
#   inflating: images/45825.png
#   inflating: images/9948.png
#   inflating: images/1065.png
#   inflating: images/33369.png
#   inflating: images/13122.png
#   inflating: images/17217.png
#   inflating: images/37689.png
#   inflating: images/10115.png
#   inflating: images/43276.png
#   inflating: images/1392.png
#   inflating: images/14450.png
#   inflating: images/37456.png
#   inflating: images/17658.png
#   inflating: images/17549.png
#   inflating: images/18743.png
#   inflating: images/45717.png
#   inflating: images/18628.png
#   inflating: images/8421.png
#   inflating: images/14252.png
#   inflating: images/44689.png
#   inflating: images/23737.png
#   inflating: images/34654.png
#   inflating: images/23846.png
#   inflating: images/2955.png
#   inflating: images/36971.png
#   inflating: images/32927.png
#   inflating: images/24935.png
#   inflating: images/23623.png
#   inflating: images/22483.png
#   inflating: images/25247.png
#   inflating: images/49594.png
#   inflating: images/22809.png
#   inflating: images/32393.png
#   inflating: images/22648.png
#   inflating: images/41810.png
#   inflating: images/38255.png
#   inflating: images/27961.png
#   inflating: images/34135.png
#   inflating: images/6567.png
#   inflating: images/19671.png
#   inflating: images/37261.png
#   inflating: images/14256.png
#   inflating: images/12969.png
#   inflating: images/13195.png
#   inflating: images/35683.png
#   inflating: images/6026.png
#   inflating: images/33702.png
#   inflating: images/44018.png
#   inflating: images/45964.png
#   inflating: images/8308.png
#   inflating: images/7188.png
#   inflating: images/33237.png
#   inflating: images/17430.png
#   inflating: images/5337.png
#   inflating: images/27816.png
#   inflating: images/11414.png
#   inflating: images/45894.png
#   inflating: images/3197.png
#   inflating: images/18753.png
#   inflating: images/36916.png
#   inflating: images/41138.png
#   inflating: images/43899.png
#   inflating: images/21151.png
#   inflating: images/9405.png
#   inflating: images/26503.png
#   inflating: images/29758.png
#   inflating: images/30528.png
#   inflating: images/1398.png
#   inflating: images/7980.png
#   inflating: images/21229.png
#   inflating: images/49642.png
#   inflating: images/42323.png
#   inflating: images/33155.png
#   inflating: images/18569.png
#   inflating: images/49680.png
#   inflating: images/31962.png
#   inflating: images/31634.png
#   inflating: images/37552.png
#   inflating: images/49512.png
#   inflating: images/47998.png
#   inflating: images/2834.png
#   inflating: images/26435.png
#   inflating: images/46958.png
#   inflating: images/32215.png
#   inflating: images/29430.png
#   inflating: images/15855.png
#   inflating: images/47553.png
#   inflating: images/36813.png
#   inflating: images/7331.png
#   inflating: images/2763.png
#   inflating: images/48713.png
#   inflating: images/31667.png
#   inflating: images/16441.png
#   inflating: images/29206.png
#   inflating: images/3854.png
#   inflating: images/11537.png
#   inflating: images/12530.png
#   inflating: images/47572.png
#   inflating: images/28654.png
#   inflating: images/25986.png
#   inflating: images/2876.png
#   inflating: images/45574.png
#   inflating: images/37405.png
#   inflating: images/1115.png
#   inflating: images/28867.png
#   inflating: images/6500.png
#   inflating: images/18724.png
#   inflating: images/44946.png
#   inflating: images/41441.png
#   inflating: images/42218.png
#   inflating: images/23907.png
#   inflating: images/14443.png
#   inflating: images/42752.png
#   inflating: images/40905.png
#   inflating: images/38484.png
#   inflating: images/8494.png
#   inflating: images/12748.png
#   inflating: images/46298.png
#   inflating: images/31826.png
#   inflating: images/36330.png
#   inflating: images/34843.png
#   inflating: images/2171.png
#   inflating: images/30980.png
#   inflating: images/41771.png
#   inflating: images/11465.png
#   inflating: images/30433.png
#   inflating: images/28198.png
#   inflating: images/32727.png
#   inflating: images/46080.png
#   inflating: images/12177.png
#   inflating: images/5996.png
#   inflating: images/7160.png
#   inflating: images/26556.png
#   inflating: images/6742.png
#   inflating: images/17846.png
#   inflating: images/43972.png
#   inflating: images/38636.png
#   inflating: images/46885.png
#   inflating: images/15403.png
#   inflating: images/22587.png
#   inflating: images/49589.png
#   inflating: images/24197.png
#   inflating: images/6511.png
#   inflating: images/6982.png
#   inflating: images/17625.png
#   inflating: images/6254.png
#   inflating: images/45154.png
#   inflating: images/15756.png
#   inflating: images/18665.png
#   inflating: images/32386.png
#   inflating: images/49057.png
#   inflating: images/25009.png
#   inflating: images/3152.png
#   inflating: images/17894.png
#   inflating: images/33898.png
#   inflating: images/15678.png
#   inflating: images/31541.png
#   inflating: images/29204.png
#   inflating: images/28402.png
#   inflating: images/42981.png
#   inflating: images/26720.png
#   inflating: images/34260.png
#   inflating: images/7224.png
#   inflating: images/15157.png
#   inflating: images/25144.png
#   inflating: images/28263.png
#   inflating: images/35562.png
#   inflating: images/42612.png
#   inflating: images/1381.png
#   inflating: images/32835.png
#   inflating: images/31468.png
#   inflating: images/2540.png
#   inflating: images/49024.png
#   inflating: images/2308.png
#   inflating: images/33803.png
#   inflating: images/4267.png
#   inflating: images/147.png
#   inflating: images/12005.png
#   inflating: images/11641.png
#   inflating: images/25500.png
#   inflating: images/23914.png
#   inflating: images/21708.png
#   inflating: images/14471.png
#   inflating: images/47302.png
#   inflating: images/29596.png
#   inflating: images/39968.png
#   inflating: images/31866.png
#   inflating: images/30461.png
#   inflating: images/18489.png
#   inflating: images/16258.png
#   inflating: images/8009.png
#   inflating: images/20975.png
#   inflating: images/23344.png
#   inflating: images/24011.png
#   inflating: images/2292.png
#   inflating: images/8903.png
#   inflating: images/18070.png
#   inflating: images/9928.png
#   inflating: images/49401.png
#   inflating: images/13506.png
#   inflating: images/20318.png
#   inflating: images/48150.png
#   inflating: images/46099.png
#   inflating: images/22436.png
#   inflating: images/46226.png
#   inflating: images/36940.png
#   inflating: images/19423.png
#   inflating: images/26360.png
#   inflating: images/42519.png
#   inflating: images/40747.png
#   inflating: images/4685.png
#   inflating: images/46985.png
#   inflating: images/49930.png
#   inflating: images/31873.png
#   inflating: images/24560.png
#   inflating: images/48541.png
#   inflating: images/24742.png
#   inflating: images/1913.png
#   inflating: images/13097.png
#   inflating: images/36875.png
#   inflating: images/27256.png
#   inflating: images/1867.png
#   inflating: images/35668.png
#   inflating: images/26788.png
#   inflating: images/523.png
#   inflating: images/43588.png
#   inflating: images/15317.png
#   inflating: images/12003.png
#   inflating: images/45873.png
#   inflating: images/26638.png
#   inflating: images/18424.png
#   inflating: images/47845.png
#   inflating: images/24452.png
#   inflating: images/7604.png
#   inflating: images/32970.png
#   inflating: images/25857.png
#   inflating: images/32601.png
#   inflating: images/17343.png
#   inflating: images/12866.png
#   inflating: images/12054.png
#   inflating: images/368.png
#   inflating: images/24316.png
#   inflating: images/23868.png
#   inflating: images/39490.png
#   inflating: images/43268.png
#   inflating: images/38298.png
#   inflating: images/11391.png
#   inflating: images/6344.png
#   inflating: images/35199.png
#   inflating: images/44745.png
#   inflating: images/24928.png
#   inflating: images/44841.png
#   inflating: images/33798.png
#   inflating: images/32428.png
#   inflating: images/25451.png
#   inflating: images/12443.png
#   inflating: images/28156.png
#   inflating: images/16154.png
#   inflating: images/35959.png
#   inflating: images/7088.png
#   inflating: images/21149.png
#   inflating: images/42314.png
#   inflating: images/20852.png
#   inflating: images/34024.png
#   inflating: images/5127.png
#   inflating: images/42626.png
#   inflating: images/32589.png
#   inflating: images/37987.png
#   inflating: images/8732.png
#   inflating: images/48930.png
#   inflating: images/8489.png
#   inflating: images/17244.png
#   inflating: images/18032.png
#   inflating: images/33037.png
#   inflating: images/47850.png
#   inflating: images/8090.png
#   inflating: images/31978.png
#   inflating: images/41200.png
#   inflating: images/10184.png
#   inflating: images/30314.png
#   inflating: images/45233.png
#   inflating: images/40425.png
#   inflating: images/44443.png
#   inflating: images/5075.png
#   inflating: images/25746.png
#   inflating: images/20903.png
#   inflating: images/12871.png
#   inflating: images/39672.png
#   inflating: images/38515.png
#   inflating: images/13538.png
#   inflating: images/12790.png
#   inflating: images/21735.png
#   inflating: images/6638.png
#   inflating: images/16779.png
#   inflating: images/22972.png
#   inflating: images/23468.png
#   inflating: images/47471.png
#   inflating: images/23735.png
#   inflating: images/13105.png
#   inflating: images/2659.png
#   inflating: images/15139.png
#   inflating: images/39663.png
#   inflating: images/16729.png
#   inflating: images/49432.png
#   inflating: images/40459.png
#   inflating: images/46780.png
#   inflating: images/31337.png
#   inflating: images/25180.png
#   inflating: images/8210.png
#   inflating: images/15559.png
#   inflating: images/14593.png
#   inflating: images/48770.png
#   inflating: images/10256.png
#   inflating: images/26222.png
#   inflating: images/8155.png
#   inflating: images/10400.png
#   inflating: images/40828.png
#   inflating: images/42786.png
#   inflating: images/49833.png
#   inflating: images/2524.png
#   inflating: images/19541.png
#   inflating: images/3514.png
#   inflating: images/28542.png
#   inflating: images/34798.png
#   inflating: images/25368.png
#   inflating: images/4544.png
#   inflating: images/49418.png
#   inflating: images/44017.png
#   inflating: images/30764.png
#   inflating: images/31801.png
#   inflating: images/40196.png
#   inflating: images/21949.png
#   inflating: images/17293.png
#   inflating: images/43014.png
#   inflating: images/38553.png
#   inflating: images/42483.png
#   inflating: images/22298.png
#   inflating: images/42239.png
#   inflating: images/6392.png
#   inflating: images/41735.png
#   inflating: images/46493.png
#   inflating: images/38768.png
#   inflating: images/43836.png
#   inflating: images/38309.png
#   inflating: images/31581.png
#   inflating: images/19093.png
#   inflating: images/9797.png
#   inflating: images/47887.png
#   inflating: images/44536.png
#   inflating: images/15598.png
#   inflating: images/13294.png
#   inflating: images/37529.png
#   inflating: images/13584.png
#   inflating: images/18856.png
#   inflating: images/26327.png
#   inflating: images/39060.png
#   inflating: images/750.png
#   inflating: images/21770.png
#   inflating: images/32231.png
#   inflating: images/17414.png
#   inflating: images/5529.png
#   inflating: images/29516.png
#   inflating: images/3057.png
#   inflating: images/22902.png
#   inflating: images/48297.png
#   inflating: images/27379.png
#   inflating: images/9697.png
#   inflating: images/43128.png
#   inflating: images/33753.png
#   inflating: images/10262.png
#   inflating: images/14958.png
#   inflating: images/26593.png
#   inflating: images/36581.png
#   inflating: images/24062.png
#   inflating: images/19239.png
#   inflating: images/38536.png
#   inflating: images/36839.png
#   inflating: images/1062.png
#   inflating: images/21102.png
#   inflating: images/40049.png
#   inflating: images/15583.png
#   inflating: images/21938.png
#   inflating: images/22295.png
#   inflating: images/28021.png
#   inflating: images/11436.png
#   inflating: images/28483.png
#   inflating: images/632.png
#   inflating: images/38809.png
#   inflating: images/5876.png
#   inflating: images/41377.png
#   inflating: images/1967.png
#   inflating: images/48946.png
#   inflating: images/23789.png
#   inflating: images/6538.png
#   inflating: images/44441.png
#   inflating: images/34913.png
#   inflating: images/12008.png
#   inflating: images/42223.png
#   inflating: images/12346.png
#   inflating: images/32058.png
#   inflating: images/6856.png
#   inflating: images/48600.png
#   inflating: images/26676.png
#   inflating: images/20948.png
#   inflating: images/13896.png
#   inflating: images/30934.png
#   inflating: images/39526.png
#   inflating: images/21977.png
#   inflating: images/34889.png
#   inflating: images/19902.png
#   inflating: images/10935.png
#   inflating: images/37822.png
#   inflating: images/43248.png
#   inflating: images/11338.png
#   inflating: images/30015.png
#   inflating: images/14032.png
#   inflating: images/28144.png
#   inflating: images/45213.png
#   inflating: images/2842.png
#   inflating: images/32786.png
#   inflating: images/45712.png
#   inflating: images/35535.png
#   inflating: images/37260.png
#   inflating: images/1598.png
#   inflating: images/43283.png
#   inflating: images/5744.png
#   inflating: images/38392.png
#   inflating: images/32633.png
#   inflating: images/31011.png
#   inflating: images/5058.png
#   inflating: images/4671.png
#   inflating: images/46272.png
#   inflating: images/20446.png
#   inflating: images/1608.png
#   inflating: images/10027.png
#   inflating: images/26718.png
#   inflating: images/7516.png
#   inflating: images/5002.png
#   inflating: images/45374.png
#   inflating: images/17986.png
#   inflating: images/29429.png
#   inflating: images/28055.png
#   inflating: images/34700.png
#   inflating: images/18611.png
#   inflating: images/34599.png
#   inflating: images/20287.png
#   inflating: images/33672.png
#   inflating: images/5423.png
#   inflating: images/38324.png
#   inflating: images/10641.png
#   inflating: images/36955.png
#   inflating: images/20595.png
#   inflating: images/28281.png
#   inflating: images/27592.png
#   inflating: images/34605.png
#   inflating: images/37747.png
#   inflating: images/11687.png
#   inflating: images/42048.png
#   inflating: images/43797.png
#   inflating: images/40024.png
#   inflating: images/14507.png
#   inflating: images/26502.png
#   inflating: images/22662.png
#   inflating: images/48375.png
#   inflating: images/35684.png
#   inflating: images/34712.png
#   inflating: images/10952.png
#   inflating: images/37699.png
#   inflating: images/28289.png
#   inflating: images/2247.png
#   inflating: images/15016.png
#   inflating: images/41755.png
#   inflating: images/3522.png
#   inflating: images/27518.png
#   inflating: images/43497.png
#   inflating: images/26473.png
#   inflating: images/42046.png
#   inflating: images/29083.png
#   inflating: images/2992.png
#   inflating: images/22586.png
#   inflating: images/21647.png
#   inflating: images/34450.png
#   inflating: images/29037.png
#   inflating: images/10888.png
#   inflating: images/47618.png
#   inflating: images/26292.png
#   inflating: images/39641.png
#   inflating: images/46106.png
#   inflating: images/44075.png
#   inflating: images/30430.png
#   inflating: images/26985.png
#   inflating: images/15220.png
#   inflating: images/12940.png
#   inflating: images/23499.png
#   inflating: images/42291.png
#   inflating: images/36062.png
#   inflating: images/4346.png
#   inflating: images/25572.png
#   inflating: images/14469.png
#   inflating: images/41895.png
#   inflating: images/7367.png
#   inflating: images/15771.png
#   inflating: images/40635.png
#   inflating: images/14247.png
#   inflating: images/27388.png
#   inflating: images/30108.png
#   inflating: images/3382.png
#   inflating: images/6801.png
#   inflating: images/42862.png
#   inflating: images/1150.png
#   inflating: images/33183.png
#   inflating: images/36269.png
#   inflating: images/27284.png
#   inflating: images/45327.png
#   inflating: images/42824.png
#   inflating: images/28539.png
#   inflating: images/23152.png
#   inflating: images/26415.png
#   inflating: images/29671.png
#   inflating: images/37973.png
#   inflating: images/15079.png
#   inflating: images/4832.png
#   inflating: images/3151.png
#   inflating: images/28785.png
#   inflating: images/23940.png
#   inflating: images/10240.png
#   inflating: images/34381.png
#   inflating: images/48603.png
#   inflating: images/47957.png
#   inflating: images/22350.png
#   inflating: images/27886.png
#   inflating: images/49130.png
#   inflating: images/18268.png
#   inflating: images/25621.png
#   inflating: images/12281.png
#   inflating: images/45034.png
#   inflating: images/32072.png
#   inflating: images/19498.png
#   inflating: images/1260.png
#   inflating: images/34442.png
#   inflating: images/32454.png
#   inflating: images/27625.png
#   inflating: images/35353.png
#   inflating: images/14172.png
#   inflating: images/5167.png
#   inflating: images/23673.png
#   inflating: images/8800.png
#   inflating: images/2705.png
#   inflating: images/9576.png
#   inflating: images/29265.png
#   inflating: images/32202.png
#   inflating: images/44503.png
#   inflating: images/31143.png
#   inflating: images/24311.png
#   inflating: images/44502.png
#   inflating: images/17936.png
#   inflating: images/26479.png
#   inflating: images/49453.png
#   inflating: images/20579.png
#   inflating: images/47024.png
#   inflating: images/32779.png
#   inflating: images/4057.png
#   inflating: images/41449.png
#   inflating: images/39906.png
#   inflating: images/41968.png
#   inflating: images/5158.png
#   inflating: images/6677.png
#   inflating: images/45854.png
#   inflating: images/30623.png
#   inflating: images/41795.png
#   inflating: images/18055.png
#   inflating: images/3359.png
#   inflating: images/22787.png
#   inflating: images/26143.png
#   inflating: images/40605.png
#   inflating: images/32544.png
#   inflating: images/36805.png
#   inflating: images/15845.png
#   inflating: images/18243.png
#   inflating: images/12848.png
#   inflating: images/44938.png
#   inflating: images/32199.png
#   inflating: images/7997.png
#   inflating: images/24615.png
#   inflating: images/42086.png
#   inflating: images/42410.png
#   inflating: images/47118.png
#   inflating: images/31570.png
#   inflating: images/34191.png
#   inflating: images/13971.png
#   inflating: images/16675.png
#   inflating: images/677.png
#   inflating: images/3479.png
#   inflating: images/26648.png
#   inflating: images/39861.png
#   inflating: images/47490.png
#   inflating: images/18814.png
#   inflating: images/28681.png
#   inflating: images/24169.png
#   inflating: images/25033.png
#   inflating: images/8467.png
#   inflating: images/36640.png
#   inflating: images/17476.png
#   inflating: images/23539.png
#   inflating: images/23080.png
#   inflating: images/47657.png
#   inflating: images/26248.png
#   inflating: images/32821.png
#   inflating: images/20980.png
#   inflating: images/24603.png
#   inflating: images/20691.png
#   inflating: images/19782.png
#   inflating: images/41936.png
#   inflating: images/36697.png
#   inflating: images/25814.png
#   inflating: images/8525.png
#   inflating: images/14426.png
#   inflating: images/27577.png
#   inflating: images/15128.png
#   inflating: images/32638.png
#   inflating: images/6937.png
#   inflating: images/9206.png
#   inflating: images/10813.png
#   inflating: images/11244.png
#   inflating: images/17102.png
#   inflating: images/23245.png
#   inflating: images/36298.png
#   inflating: images/37841.png
#   inflating: images/45509.png
#   inflating: images/10538.png
#   inflating: images/32759.png
#   inflating: images/36324.png
#   inflating: images/28545.png
#   inflating: images/36845.png
#   inflating: images/49897.png
#   inflating: images/1146.png
#   inflating: images/12095.png
#   inflating: images/2427.png
#   inflating: images/39908.png
#   inflating: images/29334.png
#   inflating: images/48169.png
#   inflating: images/43058.png
#   inflating: images/10135.png
#   inflating: images/38035.png
#   inflating: images/33324.png
#   inflating: images/32660.png
#   inflating: images/44304.png
#   inflating: images/1068.png
#   inflating: images/45121.png
#   inflating: images/44856.png
#   inflating: images/16314.png
#   inflating: images/24524.png
#   inflating: images/13429.png
#   inflating: images/47511.png
#   inflating: images/22740.png
#   inflating: images/8334.png
#   inflating: images/16147.png
#   inflating: images/2666.png
#   inflating: images/11708.png
#   inflating: images/31895.png
#   inflating: images/48796.png
#   inflating: images/43332.png
#   inflating: images/32317.png
#   inflating: images/38174.png
#   inflating: images/3762.png
#   inflating: images/2383.png
#   inflating: images/5875.png
#   inflating: images/37778.png
#   inflating: images/47237.png
#   inflating: images/34606.png
#   inflating: images/39399.png
#   inflating: images/10679.png
#   inflating: images/29149.png
#   inflating: images/5313.png
#   inflating: images/11343.png
#   inflating: images/46145.png
#   inflating: images/14747.png
#   inflating: images/28904.png
#   inflating: images/31240.png
#   inflating: images/16381.png
#   inflating: images/30082.png
#   inflating: images/22441.png
#   inflating: images/25353.png
#   inflating: images/41185.png
#   inflating: images/8964.png
#   inflating: images/34942.png
#   inflating: images/16559.png
#   inflating: images/17221.png
#   inflating: images/4200.png
#   inflating: images/17211.png
#   inflating: images/15478.png
#   inflating: images/3725.png
#   inflating: images/29865.png
#   inflating: images/42064.png
#   inflating: images/49832.png
#   inflating: images/3062.png
#   inflating: images/40515.png
#   inflating: images/27739.png
#   inflating: images/26951.png
#   inflating: images/13583.png
#   inflating: images/46185.png
#   inflating: images/121.png
#   inflating: images/46171.png
#   inflating: images/6376.png
#   inflating: images/30416.png
#   inflating: images/3625.png
#   inflating: images/46963.png
#   inflating: images/1425.png
#   inflating: images/14420.png
#   inflating: images/11790.png
#   inflating: images/500.png
#   inflating: images/35188.png
#   inflating: images/19876.png
#   inflating: images/13999.png
#   inflating: images/47324.png
#   inflating: images/25559.png
#   inflating: images/21912.png
#   inflating: images/20831.png
#   inflating: images/24229.png
#   inflating: images/12386.png
#   inflating: images/13224.png
#   inflating: images/34439.png
#   inflating: images/32608.png
#   inflating: images/2355.png
#   inflating: images/38752.png
#   inflating: images/42210.png
#   inflating: images/11737.png
#   inflating: images/47285.png
#   inflating: images/38690.png
#   inflating: images/41061.png
#   inflating: images/12845.png
#   inflating: images/20504.png
#   inflating: images/43510.png
#   inflating: images/44615.png
#   inflating: images/30635.png
#   inflating: images/20634.png
#   inflating: images/22985.png
#   inflating: images/4365.png
#   inflating: images/9240.png
#   inflating: images/17652.png
#   inflating: images/42702.png
#   inflating: images/28327.png
#   inflating: images/6701.png
#   inflating: images/8402.png
#   inflating: images/11503.png
#   inflating: images/15.png
#   inflating: images/43003.png
#   inflating: images/42271.png
#   inflating: images/14649.png
#   inflating: images/23880.png
#   inflating: images/12955.png
#   inflating: images/10889.png
#   inflating: images/37118.png
#   inflating: images/21432.png
#   inflating: images/28084.png
#   inflating: images/30056.png
#   inflating: images/47889.png
#   inflating: images/644.png
#   inflating: images/49347.png
#   inflating: images/13134.png
#   inflating: images/22169.png
#   inflating: images/46770.png
#   inflating: images/40299.png
#   inflating: images/39928.png
#   inflating: images/7918.png
#   inflating: images/40405.png
#   inflating: images/37814.png
#   inflating: images/37913.png
#   inflating: images/18136.png
#   inflating: images/20727.png
#   inflating: images/29970.png
#   inflating: images/6906.png
#   inflating: images/45520.png
#   inflating: images/6407.png
#   inflating: images/49652.png
#   inflating: images/41023.png
#   inflating: images/19800.png
#   inflating: images/41876.png
#   inflating: images/42058.png
#   inflating: images/24380.png
#   inflating: images/29968.png
#   inflating: images/25732.png
#   inflating: images/35706.png
#   inflating: images/32200.png
#   inflating: images/39445.png
#   inflating: images/46217.png
#   inflating: images/45343.png
#   inflating: images/38.png
#   inflating: images/49882.png
#   inflating: images/15107.png
#   inflating: images/46911.png
#   inflating: images/21384.png
#   inflating: images/5033.png
#   inflating: images/24800.png
#   inflating: images/20451.png
#   inflating: images/11767.png
#   inflating: images/28773.png
#   inflating: images/16520.png
#   inflating: images/27615.png
#   inflating: images/35786.png
#   inflating: images/37397.png
#   inflating: images/11918.png
#   inflating: images/48417.png
#   inflating: images/31516.png
#   inflating: images/23174.png
#   inflating: images/14458.png
#   inflating: images/36023.png
#   inflating: images/361.png
#   inflating: images/48437.png
#   inflating: images/11130.png
#   inflating: images/21468.png
#   inflating: images/24520.png
#   inflating: images/41761.png
#   inflating: images/36979.png
#   inflating: images/29290.png
#   inflating: images/5087.png
#   inflating: images/6473.png
#   inflating: images/31656.png
#   inflating: images/34204.png
#   inflating: images/42933.png
#   inflating: images/33123.png
#   inflating: images/20208.png
#   inflating: images/1634.png
#   inflating: images/13707.png
#   inflating: images/8619.png
#   inflating: images/24252.png
#   inflating: images/47327.png
#   inflating: images/29409.png
#   inflating: images/12483.png
#   inflating: images/27102.png
#   inflating: images/15018.png
#   inflating: images/10956.png
#   inflating: images/8137.png
#   inflating: images/44128.png
#   inflating: images/46663.png
#   inflating: images/32952.png
#   inflating: images/6700.png
#   inflating: images/15776.png
#   inflating: images/22086.png
#   inflating: images/12504.png
#   inflating: images/6513.png
#   inflating: images/33924.png
#   inflating: images/26943.png
#   inflating: images/43954.png
#   inflating: images/14279.png
#   inflating: images/3460.png
#   inflating: images/45579.png
#   inflating: images/4434.png
#   inflating: images/38765.png
#   inflating: images/3415.png
#   inflating: images/2946.png
#   inflating: images/7400.png
#   inflating: images/33104.png
#   inflating: images/15056.png
#   inflating: images/49143.png
#   inflating: images/27016.png
#   inflating: images/453.png
#   inflating: images/25504.png
#   inflating: images/1328.png
#   inflating: images/17810.png
#   inflating: images/26049.png
#   inflating: images/19230.png
#   inflating: images/32605.png
#   inflating: images/10884.png
#   inflating: images/16611.png
#   inflating: images/9981.png
#   inflating: images/38862.png
#   inflating: images/8569.png
#   inflating: images/16459.png
#   inflating: images/43568.png
#   inflating: images/4018.png
#   inflating: images/24293.png
#   inflating: images/32250.png
#   inflating: images/15040.png
#   inflating: images/14637.png
#   inflating: images/30378.png
#   inflating: images/15281.png
#   inflating: images/10543.png
#   inflating: images/16782.png
#   inflating: images/16257.png
#   inflating: images/14046.png
#   inflating: images/16091.png
#   inflating: images/16631.png
#   inflating: images/14415.png
#   inflating: images/46853.png
#   inflating: images/30813.png
#   inflating: images/3339.png
#   inflating: images/31118.png
#   inflating: images/30738.png
#   inflating: images/48262.png
#   inflating: images/29238.png
#   inflating: images/10131.png
#   inflating: images/19396.png
#   inflating: images/20.png
#   inflating: images/16997.png
#   inflating: images/8981.png
#   inflating: images/43373.png
#   inflating: images/8794.png
#   inflating: images/26223.png
#   inflating: images/25521.png
#   inflating: images/35025.png
#   inflating: images/25752.png
#   inflating: images/12995.png
#   inflating: images/25795.png
#   inflating: images/18847.png
#   inflating: images/6862.png
#   inflating: images/22744.png
#   inflating: images/28264.png
#   inflating: images/17372.png
#   inflating: images/24840.png
#   inflating: images/9670.png
#   inflating: images/30786.png
#   inflating: images/45329.png
#   inflating: images/42022.png
#   inflating: images/49472.png
#   inflating: images/9994.png
#   inflating: images/6767.png
#   inflating: images/18931.png
#   inflating: images/36137.png
#   inflating: images/26837.png
#   inflating: images/29857.png
#   inflating: images/43140.png
#   inflating: images/6474.png
#   inflating: images/544.png
#   inflating: images/45397.png
#   inflating: images/24613.png
#   inflating: images/15443.png
#   inflating: images/26964.png
#   inflating: images/41778.png
#   inflating: images/25360.png
#   inflating: images/43988.png
#   inflating: images/35273.png
#   inflating: images/36867.png
#   inflating: images/45024.png
#   inflating: images/48695.png
#   inflating: images/15829.png
#   inflating: images/13705.png
#   inflating: images/42122.png
#   inflating: images/36873.png
#   inflating: images/8352.png
#   inflating: images/10341.png
#   inflating: images/7452.png
#   inflating: images/36176.png
#   inflating: images/28702.png
#   inflating: images/2428.png
#   inflating: images/23717.png
#   inflating: images/32612.png
#   inflating: images/35347.png
#   inflating: images/2112.png
#   inflating: images/31806.png
#   inflating: images/31859.png
#   inflating: images/21580.png
#   inflating: images/40547.png
#   inflating: images/13382.png
#   inflating: images/15496.png
#   inflating: images/24339.png
#   inflating: images/12584.png
#   inflating: images/49550.png
#   inflating: images/20229.png
#   inflating: images/18966.png
#   inflating: images/21055.png
#   inflating: images/6228.png
#   inflating: images/49068.png
#   inflating: images/41483.png
#   inflating: images/13198.png
#   inflating: images/16956.png
#   inflating: images/14363.png
#   inflating: images/4802.png
#   inflating: images/13744.png
#   inflating: images/36529.png
#   inflating: images/17512.png
#   inflating: images/15023.png
#   inflating: images/2459.png
#   inflating: images/31503.png
#   inflating: images/48143.png
#   inflating: images/134.png
#   inflating: images/32451.png
#   inflating: images/41640.png
#   inflating: images/43573.png
#   inflating: images/49391.png
#   inflating: images/46584.png
#   inflating: images/17170.png
#   inflating: images/2483.png
#   inflating: images/12875.png
#   inflating: images/24558.png
#   inflating: images/3313.png
#   inflating: images/14522.png
#   inflating: images/37348.png
#   inflating: images/9765.png
#   inflating: images/17551.png
#   inflating: images/41507.png
#   inflating: images/42209.png
#   inflating: images/23236.png
#   inflating: images/27369.png
#   inflating: images/8378.png
#   inflating: images/31681.png
#   inflating: images/46805.png
#   inflating: images/1371.png
#   inflating: images/35329.png
#   inflating: images/31018.png
#   inflating: images/2562.png
#   inflating: images/29394.png
#   inflating: images/42437.png
#   inflating: images/40410.png
#   inflating: images/17675.png
#   inflating: images/328.png
#   inflating: images/24275.png
#   inflating: images/43805.png
#   inflating: images/10134.png
#   inflating: images/29707.png
#   inflating: images/14220.png
#   inflating: images/18448.png
#   inflating: images/24866.png
#   inflating: images/49634.png
#   inflating: images/24526.png
#   inflating: images/3559.png
#   inflating: images/23570.png
#   inflating: images/11473.png
#   inflating: images/46920.png
#   inflating: images/31019.png
#   inflating: images/27300.png
#   inflating: images/1224.png
#   inflating: images/13665.png
#   inflating: images/27098.png
#   inflating: images/37819.png
#   inflating: images/45313.png
#   inflating: images/33713.png
#   inflating: images/33534.png
#   inflating: images/29577.png
#   inflating: images/42734.png
#   inflating: images/45359.png
#   inflating: images/5121.png
#   inflating: images/46257.png
#   inflating: images/2644.png
#   inflating: images/6175.png
#   inflating: images/29681.png
#   inflating: images/13054.png
#   inflating: images/43757.png
#   inflating: images/24399.png
#   inflating: images/12463.png
#   inflating: images/39639.png
#   inflating: images/2139.png
#   inflating: images/21030.png
#   inflating: images/4255.png
#   inflating: images/16614.png
#   inflating: images/31723.png
#   inflating: images/19509.png
#   inflating: images/35362.png
#   inflating: images/26698.png
#   inflating: images/39664.png
#   inflating: images/20607.png
#   inflating: images/22282.png
#   inflating: images/12605.png
#   inflating: images/27598.png
#   inflating: images/29251.png
#   inflating: images/42755.png
#   inflating: images/35851.png
#   inflating: images/19775.png
#   inflating: images/38671.png
#   inflating: images/2120.png
#   inflating: images/11508.png
#   inflating: images/23442.png
#   inflating: images/21154.png
#   inflating: images/8118.png
#   inflating: images/10765.png
#   inflating: images/38181.png
#   inflating: images/47147.png
#   inflating: images/37125.png
#   inflating: images/14548.png
#   inflating: images/27906.png
# ...
#   inflating: images/6113.png
#   inflating: images/372.png
#   inflating: images/26874.png
#   inflating: images/19254.png
#   inflating: images/26280.png
#   inflating: images/7826.png
#   inflating: images/30678.png
#   inflating: images/34754.png
#   inflating: images/15409.png
#   inflating: images/20158.png
#   inflating: images/43204.png
#   inflating: images/36136.png
#   inflating: images/16279.png
#   inflating: images/23844.png
#   inflating: images/30013.png
#   inflating: images/36560.png
#   inflating: images/49893.png
#   inflating: images/29030.png
#   inflating: images/43376.png
#   inflating: images/5570.png
#   inflating: images/34705.png
#   inflating: images/960.png
#   inflating: images/17098.png
#   inflating: images/30311.png
#   inflating: images/32088.png
#   inflating: images/13853.png
#   inflating: images/38345.png
#   inflating: images/13310.png
#   inflating: images/26832.png
#   inflating: images/42126.png
#   inflating: images/21701.png
#   inflating: images/19831.png
#   inflating: images/42763.png
#   inflating: images/45723.png
#   inflating: images/42107.png
#   inflating: images/47337.png
#   inflating: images/27865.png
#   inflating: images/45578.png
#   inflating: images/17881.png
#   inflating: images/1232.png
#   inflating: images/3610.png
#   inflating: images/30639.png
#   inflating: images/9326.png
#   inflating: images/36586.png
#   inflating: images/19330.png
#   inflating: images/22080.png
#   inflating: images/21757.png
#   inflating: images/24291.png
#   inflating: images/25764.png
#   inflating: images/14309.png
#   inflating: images/20963.png
#   inflating: images/43897.png
#   inflating: images/48159.png
#   inflating: images/4438.png
#   inflating: images/2244.png
#   inflating: images/27021.png
#   inflating: images/285.png
#   inflating: images/35688.png
#   inflating: images/1956.png
#   inflating: images/28352.png
#   inflating: images/22314.png
#   inflating: images/4289.png
#   inflating: images/45145.png
#   inflating: images/9511.png
#   inflating: images/16380.png
#   inflating: images/19660.png
#   inflating: images/43690.png
#   inflating: images/31942.png
#   inflating: images/131.png
#   inflating: images/25233.png
#   inflating: images/24219.png
#   inflating: images/14424.png
#   inflating: images/32937.png
#   inflating: images/22897.png
#   inflating: images/24144.png
#   inflating: images/33255.png
#   inflating: images/27684.png
#   inflating: images/12961.png
#   inflating: images/40709.png
#   inflating: images/34200.png
#   inflating: images/3177.png
#   inflating: images/35019.png
#   inflating: images/2733.png
#   inflating: images/7430.png
#   inflating: images/41139.png
#   inflating: images/6847.png
#   inflating: images/22309.png
#   inflating: images/30076.png
#   inflating: images/29716.png
#   inflating: images/21635.png
#   inflating: images/6136.png
#   inflating: images/11581.png
#   inflating: images/27776.png
#   inflating: images/5941.png
#   inflating: images/33246.png
#   inflating: images/13837.png
#   inflating: images/36436.png
#   inflating: images/8353.png
#   inflating: images/30616.png
#   inflating: images/4728.png
#   inflating: images/44098.png
#   inflating: images/9925.png
#   inflating: images/2038.png
#   inflating: images/20261.png
#   inflating: images/4830.png
#   inflating: images/3635.png
#   inflating: images/43197.png
#   inflating: images/30210.png
#   inflating: images/49271.png
#   inflating: images/48120.png
#   inflating: images/12730.png
#   inflating: images/32136.png
#   inflating: images/12678.png
#   inflating: images/48007.png
#   inflating: images/49564.png
#   inflating: images/45928.png
#   inflating: images/7460.png
#   inflating: images/12598.png
#   inflating: images/18726.png
#   inflating: images/28593.png
#   inflating: images/45014.png
#   inflating: images/40106.png
#   inflating: images/46053.png
#   inflating: images/24470.png
#   inflating: images/38931.png
#   inflating: images/8179.png
#   inflating: images/30282.png
#   inflating: images/6876.png
#   inflating: images/13930.png
#   inflating: images/24823.png
#   inflating: images/20813.png
#   inflating: images/49523.png
#   inflating: images/37787.png
#   inflating: images/6493.png
#   inflating: images/42645.png
#   inflating: images/46766.png
#   inflating: images/47136.png
#   inflating: images/48856.png
#   inflating: images/40378.png
#   inflating: images/32705.png
#   inflating: images/33350.png
#   inflating: images/16739.png
#   inflating: images/35131.png
#   inflating: images/47172.png
#   inflating: images/14983.png
#   inflating: images/21881.png
#   inflating: images/34609.png
#   inflating: images/17868.png
#   inflating: images/14346.png
#   inflating: images/17953.png
#   inflating: images/6492.png
#   inflating: images/21676.png
#   inflating: images/13151.png
#   inflating: images/34766.png
#   inflating: images/49927.png
#   inflating: images/19531.png
#   inflating: images/25440.png
#   inflating: images/34152.png
#   inflating: images/32574.png
#   inflating: images/44318.png
#   inflating: images/25897.png
#   inflating: images/42804.png
#   inflating: images/39571.png
#   inflating: images/22371.png
#   inflating: images/45137.png
#   inflating: images/30675.png
#   inflating: images/15433.png
#   inflating: images/15274.png
#   inflating: images/23503.png
#   inflating: images/15953.png
#   inflating: images/26361.png
#   inflating: images/43360.png
#   inflating: images/47102.png
#   inflating: images/39130.png
#   inflating: images/44029.png
#   inflating: images/7534.png
#   inflating: images/25811.png
#   inflating: images/8027.png
#   inflating: images/32148.png
#   inflating: images/45060.png
#   inflating: images/43803.png
#   inflating: images/25141.png
#   inflating: images/33284.png
#   inflating: images/3957.png
#   inflating: images/23923.png
#   inflating: images/34633.png
#   inflating: images/4627.png
#   inflating: images/20179.png
#   inflating: images/9536.png
#   inflating: images/40984.png
#   inflating: images/15101.png
#   inflating: images/5374.png
#   inflating: images/21111.png
#   inflating: images/10200.png
#   inflating: images/22831.png
#   inflating: images/41809.png
#   inflating: images/29702.png
#   inflating: images/43838.png
#   inflating: images/24575.png
#   inflating: images/26620.png
#   inflating: images/6695.png
#   inflating: images/12878.png
#   inflating: images/25022.png
#   inflating: images/48824.png
#   inflating: images/18348.png
#   inflating: images/3976.png
#   inflating: images/983.png
#   inflating: images/13320.png
#   inflating: images/1993.png
#   inflating: images/49106.png
#   inflating: images/9111.png
#   inflating: images/27052.png
#   inflating: images/5056.png
#   inflating: images/7280.png
#   inflating: images/35292.png
#   inflating: images/8103.png
#   inflating: images/23191.png
#   inflating: images/31583.png
#   inflating: images/9950.png
#   inflating: images/41647.png
#   inflating: images/4442.png
#   inflating: images/24451.png
#   inflating: images/9519.png
#   inflating: images/43808.png
#   inflating: images/49938.png
#   inflating: images/24156.png
#   inflating: images/30059.png
#   inflating: images/41082.png
#   inflating: images/3700.png
#   inflating: images/10415.png
#   inflating: images/6062.png
#   inflating: images/29175.png
#   inflating: images/42312.png
#   inflating: images/6456.png
#   inflating: images/46955.png
#   inflating: images/41850.png
#   inflating: images/7774.png
#   inflating: images/13696.png
#   inflating: images/5645.png
#   inflating: images/41966.png
#   inflating: images/19694.png
#   inflating: images/45144.png
#   inflating: images/17799.png
#   inflating: images/8226.png
#   inflating: images/5750.png
#   inflating: images/31909.png
#   inflating: images/8679.png
#   inflating: images/27252.png
#   inflating: images/23496.png
#   inflating: images/9104.png
#   inflating: images/5012.png
#   inflating: images/29114.png
#   inflating: images/11827.png
#   inflating: images/45826.png
#   inflating: images/14967.png
#   inflating: images/17281.png
#   inflating: images/10635.png
#   inflating: images/26264.png
#   inflating: images/10748.png
#   inflating: images/37180.png
#   inflating: images/13922.png
#   inflating: images/6210.png
#   inflating: images/45505.png
#   inflating: images/21661.png
#   inflating: images/10628.png
#   inflating: images/41955.png
#   inflating: images/43677.png
#   inflating: images/41705.png
#   inflating: images/40371.png
#   inflating: images/18915.png
#   inflating: images/40341.png
#   inflating: images/18855.png
#   inflating: images/46679.png
#   inflating: images/28725.png
#   inflating: images/3980.png
#   inflating: images/37719.png
#   inflating: images/45747.png
#   inflating: images/33727.png
#   inflating: images/37382.png
#   inflating: images/45492.png
#   inflating: images/33710.png
#   inflating: images/14640.png
#   inflating: images/22531.png
#   inflating: images/17759.png
#   inflating: images/22956.png
#   inflating: images/1805.png
#   inflating: images/2776.png
#   inflating: images/4467.png
#   inflating: images/425.png
#   inflating: images/44651.png
#   inflating: images/1683.png
#   inflating: images/28722.png
#   inflating: images/33674.png
#   inflating: images/4809.png
#   inflating: images/43717.png
#   inflating: images/8065.png
#   inflating: images/29921.png
#   inflating: images/5516.png
#   inflating: images/30572.png
#   inflating: images/15004.png
#   inflating: images/34298.png
#   inflating: images/11292.png
#   inflating: images/10513.png
#   inflating: images/2504.png
#   inflating: images/3196.png
#   inflating: images/6420.png
#   inflating: images/18831.png
#   inflating: images/39679.png
#   inflating: images/39212.png
#   inflating: images/34653.png
#   inflating: images/28567.png
#   inflating: images/32005.png
#   inflating: images/11667.png
#   inflating: images/35733.png
#   inflating: images/1828.png
#   inflating: images/18321.png
#   inflating: images/30983.png
#   inflating: images/33895.png
#   inflating: images/15310.png
#   inflating: images/16239.png
#   inflating: images/1590.png
#   inflating: images/5684.png
#   inflating: images/42596.png
#   inflating: images/32492.png
#   inflating: images/42153.png
#   inflating: images/35721.png
#   inflating: images/31720.png
#   inflating: images/40484.png
#   inflating: images/42142.png
#   inflating: images/17638.png
#   inflating: images/25544.png
#   inflating: images/40352.png
#   inflating: images/8510.png
#   inflating: images/18832.png
#   inflating: images/34519.png
#   inflating: images/32940.png
#   inflating: images/39337.png
#   inflating: images/23159.png
#   inflating: images/46007.png
#   inflating: images/26541.png
#   inflating: images/25831.png
#   inflating: images/27948.png
#   inflating: images/17052.png
#   inflating: images/47218.png
#   inflating: images/24488.png
#   inflating: images/36882.png
#   inflating: images/15463.png
#   inflating: images/44371.png
#   inflating: images/37548.png
#   inflating: images/4148.png
#   inflating: images/48467.png
#   inflating: images/24421.png
#   inflating: images/23651.png
#   inflating: images/8648.png
#   inflating: images/24556.png
#   inflating: images/13760.png
#   inflating: images/35718.png
#   inflating: images/45179.png
#   inflating: images/45096.png
#   inflating: images/43183.png
#   inflating: images/24257.png
#   inflating: images/40918.png
#   inflating: images/9249.png
#   inflating: images/24304.png
#   inflating: images/20941.png
#   inflating: images/20000.png
#   inflating: images/9731.png
#   inflating: images/9824.png
#   inflating: images/19632.png
#   inflating: images/2147.png
#   inflating: images/5376.png
#   inflating: images/13202.png
#   inflating: images/23978.png
#   inflating: images/35811.png
#   inflating: images/20003.png
#   inflating: images/22353.png
#   inflating: images/1069.png
#   inflating: images/25596.png
#   inflating: images/7368.png
#   inflating: images/45392.png
#   inflating: images/5161.png
#   inflating: images/17972.png
#   inflating: images/38143.png
#   inflating: images/27351.png
#   inflating: images/33654.png
#   inflating: images/29631.png
#   inflating: images/31449.png
#   inflating: images/24677.png
#   inflating: images/41807.png
#   inflating: images/41420.png
#   inflating: images/42889.png
#   inflating: images/39975.png
#   inflating: images/23059.png
#   inflating: images/18651.png
#   inflating: images/19895.png
#   inflating: images/2004.png
#   inflating: images/6483.png
#   inflating: images/33145.png
#   inflating: images/21918.png
#   inflating: images/49687.png
#   inflating: images/31454.png
#   inflating: images/4309.png
#   inflating: images/37137.png
#   inflating: images/27861.png
#   inflating: images/27675.png
#   inflating: images/15582.png
#   inflating: images/1245.png
#   inflating: images/13929.png
#   inflating: images/48779.png
#   inflating: images/4625.png
#   inflating: images/42632.png
#   inflating: images/28272.png
#   inflating: images/8337.png
#   inflating: images/33221.png
#   inflating: images/35862.png
#   inflating: images/16414.png
#   inflating: images/31192.png
#   inflating: images/46619.png
#   inflating: images/46943.png
#   inflating: images/12824.png
#   inflating: images/38657.png

# %%
import cv2
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from torchvision import transforms
import math
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, TensorDataset
# %matplotlib inline

# %%
hidden_dim = 32
num_groups = 8 # Splits the N channels into this number
T = 300
batch_size = 16
dataset_size = 10000
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
class Fill50kDataset(torch.utils.data.Dataset):
    def __init__(self, folder, dataset_size, transform=None):
        self.folder = folder
        self.dataset_size = dataset_size
        self.transform = transform
        # Filter existing files to avoid errors if some indices are missing
        self.image_paths = [os.path.join(folder, f'{i}.png') for i in range(dataset_size)
                            if os.path.exists(os.path.join(folder, f'{i}.png'))]

    public_methods = ["__len__", "__getitem__"]

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        if self.transform:
            img = self.transform(img)

        # Convert to tensor and normalize to [-1, 1]
        img = torch.from_numpy(img).permute(2, 0, 1).float()
        img = (img / 127.5) - 1.0
        return (img,)

# Define transformation pipeline
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((64, 64)),
    lambda x: np.array(x)
])

# Create Dataset
full_dataset = Fill50kDataset('images', dataset_size=dataset_size, transform=transform)

# Split into Train and Dev
train_size = int(0.8 * len(full_dataset))
dev_size = len(full_dataset) - train_size
tr_dataset, dev_dataset = torch.utils.data.random_split(full_dataset, [train_size, dev_size])

# Create DataLoaders
tr_loader = DataLoader(tr_dataset, batch_size=batch_size, shuffle=True, num_workers=2)
dev_loader = DataLoader(dev_dataset, batch_size=batch_size, shuffle=False, num_workers=2)

# %% [markdown]
# # Time Embedding and Residual block

# %%
# Time step embedding
#t=0 = least noisy, t=T-1

class TimestepMLP(nn.Module):
    # A small two-layer MLP (Linear → SiLU → Linear) that takes the raw sinusoidal embedding vector and projects it into a learned representation.
    # Input size is sinusoidal_dim, output size is hidden_dim.
    # This is the "learned" part of the timestep embedding — the sinusoidal part itself has no learned parameters.
    def __init__(self, sinusoidal_dim, hidden_dim):
        super().__init__()
        self.fc1 = nn.Linear(sinusoidal_dim, hidden_dim)
        self.act = nn.SiLU()
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)

    def forward(self, t_emb):
        # t_emb: (batch, sinusoidal_dim) — output of the sinusoidal function
        x = self.fc1(t_emb)
        x = self.act(x)
        x = self.fc2(x)
        return x  # (batch, hidden_dim)

class TimeEmbedding(nn.Module):
    # The full timestep embedding module. Takes a batch of integer timesteps t (shape (batch,), ranging 0 to T-1)
    # and returns a learned embedding vector per timestep (shape (batch, hidden_dim)).
    # Internally: computes a fixed sinusoidal embedding (sin/cos at different frequencies, same family as transformer positional embeddings),
    # then passes it through TimestepMLP to produce the final learned representation.
    # Instantiated once in the UNet, called once per forward pass, output shared across all residual blocks.
    def __init__(self, sine_dim):
        super().__init__()
        self.sine_dim = sine_dim
        self.mlp = TimestepMLP(sine_dim, hidden_dim) # sine_dim = 8, hidden_dim = 32; better to have hidden_dim > sine_dim. hidden_dim is the output of the MLP

    def sinusoidal_embd(self, t):
        half_dim = self.sine_dim // 2
        freqs = torch.exp(-math.log(10000) * torch.arange(half_dim, device=t.device) / half_dim) # [half_dim] - 1D
        args = t[:, None].float() * freqs[None, :] # t * freqs; just broadcasting to multiply different shapes
        return torch.cat([torch.sin(args), torch.cos(args)], dim=-1)

    def forward(self, t):
        t_sin = self.sinusoidal_embd(t)   # (batch, sinusoidal_dim)
        return self.mlp(t_sin)                  # (batch, hidden_dim)

# %% [markdown]
# feature_map = the image at current timestep

# %%
# Residual block

class ResidualBlock(nn.Module):
    # The core building block of the UNet. Takes an image feature map x (shape (batch, in_channels, H, W)) and
    # the timestep embedding t_emb (shape (batch, hidden_dim)) and returns a new feature map (shape (batch, out_channels, H, W)).
    # Internally: two Conv2d 3x3 layers with GroupNorm and SiLU activation, with the timestep embedding injected
    # (via a small linear projection + unsqueeze) between the two convs. A skip connection (x + f(x)) wraps the whole thing
    # — uses a 1x1 Conv2d to match channels if in_channels != out_channels, otherwise Identity.
    def __init__(self, in_channels, out_channels, hidden_dim):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1)
        self.norm1 = nn.GroupNorm(num_groups, out_channels)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1)
        self.norm2 = nn.GroupNorm(num_groups, out_channels)
        self.act = nn.SiLU()
        self.t_proj = nn.Linear(hidden_dim, out_channels)
        self.skip = nn.Conv2d(in_channels, out_channels, kernel_size=1) if in_channels != out_channels else nn.Identity()

    def projTimeEmbd(self, t_emb):
        return self.t_proj(t_emb).unsqueeze(-1).unsqueeze(-1)

    def forward(self, x, t_emb):
        # first conv
        y = self.conv1(x)
        y = self.norm1(y)
        y = self.act(y)
        # inject timestep
        y = y + self.projTimeEmbd(t_emb)
        # second conv
        y = self.conv2(y)
        y = self.norm2(y)
        # skip connection
        y = y + self.skip(x)
        return y

# %%
# block = ResidualBlock(in_channels=3, out_channels=32, hidden_dim=32)
# x = torch.randn(4, 3, 64, 64)       # batch=4, 3 channels, 64x64
# t = torch.randint(0, 300, (4,))
# te = TimeEmbedding(sine_dim=8)
# t_emb = te(t)                        # (4, 32)
# out = block(x, t_emb)
# print(out.shape)                     # expect (4, 32, 64, 64)

# %% [markdown]
# # UNet
# The UNet is purely a pattern recogniser — "given this noisy image at this noise level, what noise pattern do I see?"

# %%
# downsample block

class DownSample(nn.Module):
    # Halves the spatial resolution of the feature map while increasing channel count. A single Conv2d with stride=2
    # (learnable downsampling, preferred over pooling in diffusion UNets since the kernel weights are trained).
    # Takes (batch, in_channels, H, W) → outputs (batch, out_channels, H/2, W/2).
    # No timestep embedding needed — purely a spatial operation.
    # Used at the end of each contracting stage in the UNet.
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.downsample = nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1, stride=2)

    def forward(self, x):
        return self.downsample(x)

# %%
# ds = DownSample(32, 64)
# x = torch.randn(4, 32, 64, 64)
# out = ds(x)
# print(out.shape) # expect (4, 64, 32, 32) — channels 32→64, spatial 64→32

# %%
# upsample block

class UpSample(nn.Module):
    # Doubles the spatial resolution while decreasing channel count, then concatenates the skip connection from the matching contracting stage.
    # Uses ConvTranspose2d with kernel_size=4, stride=2, padding=1 for exact 2× upsampling (no off-by-one ambiguity).
    # Takes (batch, in_channels, H, W) + skip (batch, skip_channels, H*2, W*2) → outputs (batch, out_channels + skip_channels, H*2, W*2).
    # The subsequent ResidualBlock in the expanding path receives this concatenated tensor as its in_channels.
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.upsample = nn.ConvTranspose2d(in_channels, out_channels, kernel_size=4, stride=2, padding=1)
        # kernel_size=4, stride=2, padding=1 is the standard combination for exact 2× upsampling
        # — produces output exactly double the input spatial size, no off-by-one ambiguity.
    def forward(self, x, skip):
        x = self.upsample(x)
        x = torch.cat([x, skip], dim=1)  # concatenate skip connection along channel dim
        return x

# %%
# us = UpSample(64, 32)
# x = torch.randn(4, 64, 32, 32)
# skip = torch.randn(4, 32, 64, 64)  # from matching contracting stage
# out = us(x, skip)
# print(out.shape)  # expect (4, 64, 64, 64) — 32 up-channels + 32 skip-channels

# %% [markdown]
# channels and image resolutions are different things

# %%
class UNet(nn.Module):
    def __init__(self):
        super().__init__()

        # 1. TimeEmbedding
        self.te = TimeEmbedding(sine_dim=8)

        # 2. Contracting path
        # stage 1: 3→32 channels, 64×64
        self.resDn1 = ResidualBlock(in_channels=3, out_channels=32, hidden_dim=32)
        self.ds1 = DownSample(in_channels=32, out_channels=64)
        # stage 2: 64 channels, 32×32
        self.resDn2 = ResidualBlock(in_channels=64, out_channels=64, hidden_dim=32)
        self.ds2 = DownSample(in_channels=64, out_channels=128)
        # stage 3: 128 channels, 16×16
        self.resDn3 = ResidualBlock(in_channels=128, out_channels=128, hidden_dim=32)
        self.ds3 = DownSample(in_channels=128, out_channels=256)

        # 3. Bottleneck: 256 channels, 8×8
        self.resBottle = ResidualBlock(in_channels=256, out_channels=256, hidden_dim=32)

        # 4. Expanding path
        # stage 1: upsample 256→128, concat skip(128) → 256 in for resblock
        self.us1 = UpSample(in_channels=256, out_channels=128)
        self.resUp1 = ResidualBlock(in_channels=256, out_channels=128, hidden_dim=32)
        # stage 2: upsample 128→64, concat skip(64) → 128 in for resblock
        self.us2 = UpSample(in_channels=128, out_channels=64)
        self.resUp2 = ResidualBlock(in_channels=128, out_channels=64, hidden_dim=32)
        # stage 3: upsample 64→32, concat skip(32) → 64 in for resblock
        self.us3 = UpSample(in_channels=64, out_channels=32)
        self.resUp3 = ResidualBlock(in_channels=64, out_channels=32, hidden_dim=32)

        # 5. Final conv: 32→3 channels
        self.final_conv = nn.Conv2d(32, 3, kernel_size=1)

    def forward(self, x, t):
        skipconn = []

        # 1. compute t_emb from TimeEmbedding
        t_emb = self.te(t)
        # 2. contracting path — save each stage's output as skip connection
        dn1 = self.resDn1(x, t_emb)
        skipconn.append(dn1)
        dn1 = self.ds1(dn1)

        dn2 = self.resDn2(dn1, t_emb)
        skipconn.append(dn2)
        dn2 = self.ds2(dn2)

        dn3 = self.resDn3(dn2, t_emb)
        skipconn.append(dn3)
        dn3 = self.ds3(dn3)

        # 3. bottleneck
        rsbttle = self.resBottle(dn3, t_emb)
        # 4. expanding path — pass skip connections into each UpSample
        up1 = self.us1(rsbttle, skipconn[2])
        up1 = self.resUp1(up1, t_emb)

        up2 = self.us2(up1, skipconn[1])
        up2 = self.resUp2(up2, t_emb)

        up3 = self.us3(up2, skipconn[0])
        up3 = self.resUp3(up3, t_emb)

        # 5. final conv
        return self.final_conv(up3)

# %%
# model = UNet()
# x = torch.randn(4, 3, 64, 64)
# t = torch.randint(0, 300, (4,))
# out = model(x, t)
# print(out.shape)  # expect (4, 3, 64, 64)

# %% [markdown]
# # Noise Scheduler
# The noise scheduler precomputes a table of values for every timestep t from 0 to T-1, so during training you can instantly look up "how much noise belongs at step t" without recomputing anything.
# - beta_t      — how much noise to add at this specific step (small number, e.g. 0.0001 to 0.02)
# - alpha_t     — how much of the signal remains = 1 - beta_t
# - alpha_bar_t — cumulative product of all alphas up to t = α₁ × α₂ × ... × αₜ
#
# alpha_bar_t is the important one — it's what lets you jump directly to "noisy image at step t" in one shot during training, without iterating through all previous steps.
#
# * noisy_image = sqrt(alpha_bar_t) * clean_image + sqrt(1 - alpha_bar_t) * noise
#
# Where noise is random Gaussian noise torch.randn_like(image). As t increases, alpha_bar_t shrinks toward 0 (less clean image) and 1 - alpha_bar_t grows toward 1 (more noise).

# %%
class NoiseScheduler:
    def __init__(self, T=300, beta_start=0.0001, beta_end=0.01):
        self.T = T
        # linearly spaced betas from small to large
        self.beta_t = torch.linspace(beta_start, beta_end, T)
        self.alpha_t = 1 - self.beta_t
        self.alpha_bar_t = torch.cumprod(self.alpha_t, dim=0)

    def add_noise(self, x, t, noise):
        # x: (batch, 3, 64, 64) clean image
        # t: (batch,) integer timesteps
        # noise: (batch, 3, 64, 64) random gaussian
        ab = self.alpha_bar_t[t] # (batchl, )
        a = ab.view( -1, 1, 1, 1)
        noisy_image = torch.sqrt(a) * x + torch.sqrt(1 - a) * noise # noise = torch.randn_like(x) # (batch, 3, 64, 64)—random values from N(0,1)
        return noisy_image

# %% [markdown]
# # Training loop
#
# 1. sample random t per image
# 2. sample random noise
# 3. call add_noise
# 4. pass noisy image + t into UNet
# 5. MSE between predicted noise and actual noise

# %%
model = UNet()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
scheduler = NoiseScheduler(T=300, beta_start=0.0001, beta_end=0.02)
scheduler.alpha_bar_t = scheduler.alpha_bar_t.to(device)
losses = []
model = model.to(device)

# %%
# training loop
for epoch in range(5000):
  # validation on every 100 epochs
  if epoch % 100 == 0:
    val_losses = []
    with torch.no_grad():
      for (x,) in dev_loader:
          x, t = x.to(device), torch.randint(0, T, (x.shape[0],)).to(device)
          noise = torch.randn_like(x)
          noisy_img = scheduler.add_noise(x, t, noise)
          pred_noise = model(noisy_img, t)
          val_loss = F.mse_loss(pred_noise, noise)
          val_losses.append(val_loss.item())
    print(f'epoch {epoch} | val loss {sum(val_losses)/len(val_losses):.4f}')
    model.train()

    for (x,) in tr_loader:
        x = x.to(device)
        t = torch.randint(0, 300, (x.shape[0],))
        t = t.to(device)
        noise = torch.randn_like(x)
        noise = noise.to(device)
        noisy_img = scheduler.add_noise(x, t, noise)
        noisy_img = noisy_img.to(device)
        pred_noise = model(noisy_img, t)
        loss = F.mse_loss(pred_noise, noise)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        losses.append(loss.item())

    print(f'epoch {epoch} | train loss {losses[-1]:.4f}')
# Out:
# epoch 0 | val loss 1.3364
# epoch 0 | train loss 0.0815
# epoch 100 | val loss 0.0839
# epoch 100 | train loss 0.0714
# epoch 200 | val loss 0.0531
# epoch 200 | train loss 0.0289
# epoch 300 | val loss 0.0365
# epoch 300 | train loss 0.0192
# epoch 400 | val loss 0.0311
# epoch 400 | train loss 0.0332
# epoch 500 | val loss 0.0302
# epoch 500 | train loss 0.0310
# epoch 600 | val loss 0.0215
# epoch 600 | train loss 0.0097
# epoch 700 | val loss 0.0203
# epoch 700 | train loss 0.0150
# epoch 800 | val loss 0.0166
# epoch 800 | train loss 0.0114
# epoch 900 | val loss 0.0183
# epoch 900 | train loss 0.0150
# epoch 1000 | val loss 0.0144
# epoch 1000 | train loss 0.0160
# epoch 1100 | val loss 0.0141
# epoch 1100 | train loss 0.0221
# epoch 1200 | val loss 0.0131
# epoch 1200 | train loss 0.0086
# epoch 1300 | val loss 0.0159
# epoch 1300 | train loss 0.0064
# epoch 1400 | val loss 0.0120
# epoch 1400 | train loss 0.0098
# epoch 1500 | val loss 0.0118
# epoch 1500 | train loss 0.0045
# epoch 1600 | val loss 0.0114
# epoch 1600 | train loss 0.0119
# epoch 1700 | val loss 0.0099
# epoch 1700 | train loss 0.0135
# epoch 1800 | val loss 0.0104
# epoch 1800 | train loss 0.0079
# epoch 1900 | val loss 0.0110
# epoch 1900 | train loss 0.0069
# epoch 2000 | val loss 0.0090
# epoch 2000 | train loss 0.0050
# epoch 2100 | val loss 0.0105
# epoch 2100 | train loss 0.0064
# epoch 2200 | val loss 0.0094
# epoch 2200 | train loss 0.0305
# epoch 2300 | val loss 0.0101
# epoch 2300 | train loss 0.0051
# epoch 2400 | val loss 0.0107
# epoch 2400 | train loss 0.0094
# epoch 2500 | val loss 0.0089
# epoch 2500 | train loss 0.0105
# epoch 2600 | val loss 0.0087
# epoch 2600 | train loss 0.0056
# epoch 2700 | val loss 0.0087
# epoch 2700 | train loss 0.0130
# epoch 2800 | val loss 0.0082
# epoch 2800 | train loss 0.0038
# epoch 2900 | val loss 0.0083
# epoch 2900 | train loss 0.0060
# epoch 3000 | val loss 0.0082
# epoch 3000 | train loss 0.0088
# epoch 3100 | val loss 0.0087
# epoch 3100 | train loss 0.0119
# epoch 3200 | val loss 0.0069
# epoch 3200 | train loss 0.0083
# epoch 3300 | val loss 0.0076
# epoch 3300 | train loss 0.0053
# epoch 3400 | val loss 0.0078
# epoch 3400 | train loss 0.0166
# epoch 3500 | val loss 0.0072
# epoch 3500 | train loss 0.0044
# epoch 3600 | val loss 0.0071
# epoch 3600 | train loss 0.0085
# epoch 3700 | val loss 0.0068
# epoch 3700 | train loss 0.0067
# epoch 3800 | val loss 0.0062
# epoch 3800 | train loss 0.0102
# epoch 3900 | val loss 0.0063
# epoch 3900 | train loss 0.0089
# epoch 4000 | val loss 0.0085
# epoch 4000 | train loss 0.0051
# epoch 4100 | val loss 0.0067
# epoch 4100 | train loss 0.0060
# epoch 4200 | val loss 0.0073
# epoch 4200 | train loss 0.0058
# epoch 4300 | val loss 0.0065
# epoch 4300 | train loss 0.0067
# epoch 4400 | val loss 0.0072
# epoch 4400 | train loss 0.0041
# epoch 4500 | val loss 0.0075
# epoch 4500 | train loss 0.0057
# epoch 4600 | val loss 0.0067
# epoch 4600 | train loss 0.0138
# epoch 4700 | val loss 0.0061
# epoch 4700 | train loss 0.0056
# epoch 4800 | val loss 0.0063
# epoch 4800 | train loss 0.0070
# epoch 4900 | val loss 0.0062
# epoch 4900 | train loss 0.0094

# %%
len(losses)
# Out:
# 25000

# %%
window_size = 100

# Calculate moving average
moving_avg = np.convolve(losses, np.ones(window_size)/window_size, mode='valid')
moving_avg_val = np.convolve(val_losses, np.ones(window_size)/window_size, mode='valid')

# Plot the smoothed curve
plt.plot(moving_avg, label='train')
plt.plot(moving_avg_val, label='val')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend()
plt.title('train vs val loss')
plt.show()

# %%
moving_avg = np.convolve(val_losses, np.ones(window_size)/window_size, mode='valid')
plt.plot(moving_avg, label='val')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend()
plt.title('train vs val loss')
plt.show()

# %%
def sample(model, scheduler, num_samples=4, img_size=64, device='cuda'):
    model.eval()
    with torch.no_grad():
        # Start from pure noise
        x = torch.randn((num_samples, 3, img_size, img_size)).to(device)

        # Iterate backwards from T-1 down to 0
        for t in reversed(range(scheduler.T)):
            t_batch = torch.full((num_samples,), t, device=device, dtype=torch.long)

            # Predict noise using the UNet
            pred_noise = model(x, t_batch)

            # Get scheduler parameters for current t
            alpha = scheduler.alpha_t[t].to(device)
            alpha_bar = scheduler.alpha_bar_t[t].to(device)
            beta = scheduler.beta_t[t].to(device)

            # Compute the reverse step
            if t > 0:
                noise = torch.randn_like(x)
            else:
                noise = 0

            # x_{t-1} formula
            x = (1 / torch.sqrt(alpha)) * (x - ((1 - alpha) / torch.sqrt(1 - alpha_bar)) * pred_noise) + torch.sqrt(beta) * noise

    # Post-process: map from [-1, 1] back to [0, 1]
    x = (x.clamp(-1, 1) + 1) / 2
    return x.cpu()

# %%
# Generate samples
samples = sample(model, scheduler, num_samples=4, device=device)

# Visualize
fig, axes = plt.subplots(1, 4, figsize=(15, 5))
for i in range(4):
    axes[i].imshow(samples[i].permute(1, 2, 0).numpy())
    axes[i].axis('off')
plt.suptitle("Generated Samples")
plt.show()
